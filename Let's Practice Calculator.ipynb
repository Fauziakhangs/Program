# %%
"Hello"
# Out:
# 'Hello'

# %%
import pandas as pd
import numpy as np
import requests
import json

# %%
base__url = "https://restcountries.com/v3.1/currency/cop"
base__url
# Out:
# 'https://restcountries.com/v3.1/currency/cop'

# %%
response = requests.get(base__url)
response.status_code
# Out:
# 200

# %%
data = response.json()
print(json.dumps(data, indent=2))
# Out:
# [
#   {
#     "name": {
#       "common": "Colombia",
#       "official": "Republic of Colombia",
#       "nativeName": {
#         "spa": {
#           "official": "Rep\u00fablica de Colombia",
#           "common": "Colombia"
#         }
#       }
#     },
#     "tld": [
#       ".co"
#     ],
#     "cca2": "CO",
#     "ccn3": "170",
#     "cca3": "COL",
#     "cioc": "COL",
#     "independent": true,
#     "status": "officially-assigned",
#     "unMember": true,
#     "currencies": {
#       "COP": {
#         "name": "Colombian peso",
#         "symbol": "$"
#       }
#     },
#     "idd": {
#       "root": "+5",
#       "suffixes": [
#         "7"
#       ]
#     },
#     "capital": [
#       "Bogot\u00e1"
#     ],
#     "altSpellings": [
#       "CO",
#       "Republic of Colombia",
#       "Rep\u00fablica de Colombia"
#     ],
#     "region": "Americas",
#     "subregion": "South America",
#     "languages": {
#       "spa": "Spanish"
#     },
#     "translations": {
# ...

# %%
base__url2 = base__url + "/history" +"?start_Date = 12-12-2003&end_Date=04-04-2010"
base__url2
# Out:
# 'https://restcountries.com/v3.1/currency/cop/history?start_Date = 12-12-2003&end_Date=04-04-2010'

# %%
response = requests.get(base__url2)
response.status_code # This 404 indicates error doesnot exist
# Out:
# 404

# %%
data = response.json()

# %%
print(json.dumps(data, indent = 4, sort_keys=True))
# Out:
# {
#     "_links": {
#         "self": {
#             "href": "/v3.1/currency/cop/history?start_Date%20=%2012-12-2003&end_Date=04-04-2010",
#             "templated": false
#         }
#     },
#     "message": "Page Not Found"
# }

# %%
response.json()
# Out:
# {'message': 'Page Not Found',
#  '_links': {'self': {'href': '/v3.1/currency/cop/history?start_Date%20=%2012-12-2003&end_Date=04-04-2010',
#    'templated': False}}}

# %%
# Build a calculator and take user input
# Gathering the paramters of interst
# construct the url and send a get request to it
# for unsuccessful request : print the error message
# for successful reuest : retrive the relevent data and calculate the result

# take 4 input arguments from the user:

date = input("Please input date (mm-dd-yyyy):")
base_curr = input("Please input base currency: ")
target_curr = input("Please input target currency: " )
quan_curr = float(input("Please input quantity to convert: ".formator(base)))


url = base_url + "/"+date+"?base-"+base_curr+"&symbols-"+curr
response = requests.get(url)

# %%
# Search API:

# %%
url = "https://itunes.apple.com/search"
url
# Out:
# 'https://itunes.apple.com/search'

# %%
response = requests.get(url, params={
    "term": " the beatles", "country": "us"
})
response.status_code
response.url
# Out:
# 'https://itunes.apple.com/search?term=+the+beatles&country=us'

# %%
data = response.json()
print(json.dumps(data, indent = 4 ))
# Out:
# {
#     "resultCount": 52,
#     "results": [
#         {
#             "wrapperType": "audiobook",
#             "artistId": 160778930,
#             "collectionId": 1439484338,
#             "artistName": "Bob Spitz",
#             "collectionName": "The Beatles (Abridged)",
#             "collectionCensoredName": "The Beatles (Abridged)",
#             "artistViewUrl": "https://books.apple.com/us/author/bob-spitz/id160778930?uo=4",
#             "collectionViewUrl": "https://books.apple.com/us/audiobook/the-beatles-abridged/id1439484338?uo=4",
#             "artworkUrl60": "https://is1-ssl.mzstatic.com/image/thumb/Music128/v4/69/b8/65/69b86591-ce4b-9bd0-ab71-3808d0ea06dc/9780743552455.jpg/60x60bb.jpg",
#             "artworkUrl100": "https://is1-ssl.mzstatic.com/image/thumb/Music128/v4/69/b8/65/69b86591-ce4b-9bd0-ab71-3808d0ea06dc/9780743552455.jpg/100x100bb.jpg",
#             "collectionPrice": 19.99,
#             "collectionExplicitness": "cleaned",
# ...

# %%
data.keys()
# Out:
# dict_keys(['resultCount', 'results'])

# %%
print(json.dumps(data['results'][9], indent = 4))
# Out:
# {
#     "wrapperType": "track",
#     "kind": "song",
#     "artistId": 136975,
#     "collectionId": 1441133180,
#     "trackId": 1441133834,
#     "artistName": "The Beatles",
#     "collectionName": "The Beatles (The White Album)",
#     "trackName": "Blackbird",
#     "collectionCensoredName": "The Beatles (The White Album)",
#     "trackCensoredName": "Blackbird",
#     "artistViewUrl": "https://music.apple.com/us/artist/the-beatles/136975?uo=4",
#     "collectionViewUrl": "https://music.apple.com/us/album/blackbird/1441133180?i=1441133834&uo=4",
#     "trackViewUrl": "https://music.apple.com/us/album/blackbird/1441133180?i=1441133834&uo=4",
#     "previewUrl": "https://audio-ssl.itunes.apple.com/itunes-assets/AudioPreview126/v4/81/92/53/81925382-68ea-cee8-2f91-f824ac1dc455/mzaf_8008503031387003585.plus.aac.p.m4a",
#     "artworkUrl30": "https://is1-ssl.mzstatic.com/image/thumb/Music115/v4/fa/5b/89/fa5b898d-bad6-e053-4195-260e5c74f2bb/00602567725466.rgb.jpg/30x30bb.jpg",
# ...

# %%
print(json.dumps(data['results'][2]))
# Out:
# {"wrapperType": "track", "kind": "song", "artistId": 157458, "collectionId": 282495289, "trackId": 282495296, "artistName": "Daniel Johnston", "collectionName": "Yip! Jump Music", "trackName": "The Beatles", "collectionCensoredName": "Yip! Jump Music", "trackCensoredName": "The Beatles", "artistViewUrl": "https://music.apple.com/us/artist/daniel-johnston/157458?uo=4", "collectionViewUrl": "https://music.apple.com/us/album/the-beatles/282495289?i=282495296&uo=4", "trackViewUrl": "https://music.apple.com/us/album/the-beatles/282495289?i=282495296&uo=4", "previewUrl": "https://audio-ssl.itunes.apple.com/itunes-assets/AudioPreview125/v4/e6/81/31/e68131e4-2889-d027-d1e2-6755e56fd434/mzaf_13627254640725098082.plus.aac.p.m4a", "artworkUrl30": "https://is1-ssl.mzstatic.com/image/thumb/Music/c7/24/19/mzi.hsrvxuky.jpg/30x30bb.jpg", "artworkUrl60": "https://is1-ssl.mzstatic.com/image/thumb/Music/c7/24/19/mzi.hsrvxuky.jpg/60x60bb.jpg", "artworkUrl100": "https://is1-ssl.mzstatic.com/image/thumb/M
# ...

# %%
r = requests.get(url, params ={
    'media' : 'hahahahaha', ' count' : '2321'
})
r.status_code
r.json()
# Out:
# {'errorMessage': 'Invalid value(s) for key(s): [mediaType]',
#  'queryParameters': {'output': 'json',
#   'callback': 'A javascript function to handle your search results',
#   'country': 'ISO-2A country code',
#   'limit': 'The number of search results to return',
#   'term': 'A search string',
#   'lang': 'ISO-2A language code'}}

# %%
print(json.dumps(data['results'][1:3], indent = 4))
# Out:
# [
#     {
#         "wrapperType": "audiobook",
#         "artistId": 2037074,
#         "collectionId": 1646008816,
#         "artistName": "Hunter Davies",
#         "collectionName": "The Beatles",
#         "collectionCensoredName": "The Beatles",
#         "artistViewUrl": "https://books.apple.com/us/author/hunter-davies/id2037074?uo=4",
#         "collectionViewUrl": "https://books.apple.com/us/audiobook/the-beatles/id1646008816?uo=4",
#         "artworkUrl60": "https://is1-ssl.mzstatic.com/image/thumb/Music122/v4/a9/d4/1d/a9d41dc7-12e1-c377-71fe-019d4d5116d2/2350-square.jpg/60x60bb.jpg",
#         "artworkUrl100": "https://is1-ssl.mzstatic.com/image/thumb/Music122/v4/a9/d4/1d/a9d41dc7-12e1-c377-71fe-019d4d5116d2/2350-square.jpg/100x100bb.jpg",
#         "collectionPrice": 19.99,
#         "collectionExplicitness": "cleaned",
#         "trackCount": 1,
#         "copyright": "\u00a9 1998 by Blackstone Audio, Inc.",
#         "country": "USA",
#         "currency": "USD",
# ...

# %%
pd.DataFrame(data['results']).size
# Out:
# 2288

# %%
pd.DataFrame(data['results']).dropna().size # no missing rows
# Out:
# 0

# %%
pd.DataFrame(data['results'][0:10]).loc

# %%
# .toexcel("")
# .tocsv("")

# pagination:
# I've learn how to pull data using get request.
#

# %%
# Data frame is two dimensional
import pandas as pd
import numpy as np

# numpy array 2 x 3 array/ matrix
array_a = np.array([[2,3,4], [45,66,7]])
array_a
# Out:
# array([[ 2,  3,  4],
#        [45, 66,  7]])

# %%
# duilding it into a pandas library
a = pd.DataFrame(array_a, columns=['Column 1', 'Column 2', 'Column 3'],
                index = ['Row 1', 'Row 2'])
a
# Out:
#        Column 1  Column 2  Column 3
# Row 1         2         3         4
# Row 2        45        66         7

# %%
type(a)
# Out:
# pandas.core.frame.DataFrame

# %%
data = pd.read_csv('college.csv', sep=',')
data
# Out:
#                               school Private  Accept.pct  Elite10  \
# 0       Abilene Christian University     Yes    0.742169        0
# 1                 Adelphi University     Yes    0.880146        0
# 2                     Adrian College     Yes    0.768207        0
# 3                Agnes Scott College     Yes    0.836930        1
# 4          Alaska Pacific University     Yes    0.756477        0
# ..                               ...     ...         ...      ...
# 726                  Wofford College     Yes    0.622918        1
# 727  Worcester Polytechnic Institute     Yes    0.835983        0
# 728          Worcester State College      No    0.689577        0
# 729                Xavier University     Yes    0.921388        0
# 730   Xavier University of Louisiana     Yes    0.913209        0
#
#      F.Undergrad  P.Undergrad  Outstate  Room.Board  Books  Personal  PhD  \
# 0           2885          537      7440        3300    450      2200   70
# ...

# %%
data1 = pd.DataFrame(data.loc[:, ['school', 'Private']])
data1
# Out:
#                               school Private
# 0       Abilene Christian University     Yes
# 1                 Adelphi University     Yes
# 2                     Adrian College     Yes
# 3                Agnes Scott College     Yes
# 4          Alaska Pacific University     Yes
# ..                               ...     ...
# 726                  Wofford College     Yes
# 727  Worcester Polytechnic Institute     Yes
# 728          Worcester State College      No
# 729                Xavier University     Yes
# 730   Xavier University of Louisiana     Yes
#
# [731 rows x 2 columns]

# %%
data1.isna().sum().sort_values(ascending = True).head(10)
# Out:
# school     0
# Private    0
# dtype: int64

# %%
data.columns
# Out:
# Index(['school', 'Private', 'Accept.pct', 'Elite10', 'F.Undergrad',
#        'P.Undergrad', 'Outstate', 'Room.Board', 'Books', 'Personal', 'PhD',
#        'Terminal', 'S.F.Ratio', 'perc.alumni', 'Expend', 'Grad.Rate'],
#       dtype='object')

# %%
# shape method shows the dimensionality of the data
data.shape # 731 rows and 16 columns
# Out:
# (731, 16)

# %%
len(data)
# Out:
# 731

# %%
len(data.columns)
# Out:
# 16

# %%
# how to index each element in a data frame is very crucial
# And keeping track of  data consistency is the major goal of data analysis


# Data of a specific column
pd.DataFrame(data['school'])
# Out:
#                               school
# 0       Abilene Christian University
# 1                 Adelphi University
# 2                     Adrian College
# 3                Agnes Scott College
# 4          Alaska Pacific University
# ..                               ...
# 726                  Wofford College
# 727  Worcester Polytechnic Institute
# 728          Worcester State College
# 729                Xavier University
# 730   Xavier University of Louisiana
#
# [731 rows x 1 columns]

# %%
pd.DataFrame(data[['school', 'Private']]).tail(20)
# Out:
#                               school Private
# 711           Westminster College PA     Yes
# 712          Wheeling Jesuit College     Yes
# 713                  Whitman College     Yes
# 714                 Whittier College     Yes
# 715                Whitworth College     Yes
# 716               Widener University     Yes
# 717                Wilkes University     Yes
# 718            Willamette University     Yes
# 719           William Jewell College     Yes
# 720                 Williams College     Yes
# 721                   Wilson College     Yes
# 722          Winona State University      No
# 723              Winthrop University      No
# 724       Wisconsin Lutheran College     Yes
# 725            Wittenberg University     Yes
# 726                  Wofford College     Yes
# 727  Worcester Polytechnic Institute     Yes
# 728          Worcester State College      No
# 729                Xavier University     Yes
# 730   Xavier University of Louisiana     Yes

# %%
data[['school', 'Private']]
# Out:
#                               school Private
# 0       Abilene Christian University     Yes
# 1                 Adelphi University     Yes
# 2                     Adrian College     Yes
# 3                Agnes Scott College     Yes
# 4          Alaska Pacific University     Yes
# ..                               ...     ...
# 726                  Wofford College     Yes
# 727  Worcester Polytechnic Institute     Yes
# 728          Worcester State College      No
# 729                Xavier University     Yes
# 730   Xavier University of Louisiana     Yes
#
# [731 rows x 2 columns]

# %%
locao = ['school', 'Private'] # Professionals prefer this approach
pd.DataFrame(data[locao]).head(7)
# Out:
#                          school Private
# 0  Abilene Christian University     Yes
# 1            Adelphi University     Yes
# 2                Adrian College     Yes
# 3           Agnes Scott College     Yes
# 4     Alaska Pacific University     Yes
# 5             Albertson College     Yes
# 6       Albertus Magnus College     Yes

# %%
# iloc indexing for qualitative columns
# attribute indexing ()
# iloc(int location)
# integer location / position based indexing


data.iloc[7,1] # this will fecth 7th rows and first column
# Out:
# 'Yes'

# %%
data.iloc[:, 0]
# Out:
# 0         Abilene Christian University
# 1                   Adelphi University
# 2                       Adrian College
# 3                  Agnes Scott College
# 4            Alaska Pacific University
#                     ...
# 726                    Wofford College
# 727    Worcester Polytechnic Institute
# 728            Worcester State College
# 729                  Xavier University
# 730     Xavier University of Louisiana
# Name: school, Length: 731, dtype: object

# %%
data.iloc[:, :]
# Out:
#                               school Private  Accept.pct  Elite10  \
# 0       Abilene Christian University     Yes    0.742169        0
# 1                 Adelphi University     Yes    0.880146        0
# 2                     Adrian College     Yes    0.768207        0
# 3                Agnes Scott College     Yes    0.836930        1
# 4          Alaska Pacific University     Yes    0.756477        0
# ..                               ...     ...         ...      ...
# 726                  Wofford College     Yes    0.622918        1
# 727  Worcester Polytechnic Institute     Yes    0.835983        0
# 728          Worcester State College      No    0.689577        0
# 729                Xavier University     Yes    0.921388        0
# 730   Xavier University of Louisiana     Yes    0.913209        0
#
#      F.Undergrad  P.Undergrad  Outstate  Room.Board  Books  Personal  PhD  \
# 0           2885          537      7440        3300    450      2200   70
# ...

# %%
type(data.iloc[1,9])
# Out:
# numpy.int64

# %%
pd.DataFrame(data.iloc[1, :]) # retrive only 2'nd row's details
# iloc(int  location): this is used to position based indexing or int indexing
# to retrive the column and row of interest
# and ype function retrive the type fucntion of this object
# Out:
#                               1
# school       Adelphi University
# Private                     Yes
# Accept.pct             0.880146
# Elite10                       0
# F.Undergrad                2683
# P.Undergrad                1227
# Outstate                  12280
# Room.Board                 6450
# Books                       750
# Personal                   1500
# PhD                          29
# Terminal                     30
# S.F.Ratio                  12.2
# perc.alumni                  16
# Expend                    10527
# Grad.Rate                    56

# %%
data.iloc[:, [3,1]] # allowed to change the order of the list
# Out:
#      Elite10 Private
# 0          0     Yes
# 1          0     Yes
# 2          0     Yes
# 3          1     Yes
# 4          0     Yes
# ..       ...     ...
# 726        1     Yes
# 727        0     Yes
# 728        0      No
# 729        0     Yes
# 730        0     Yes
#
# [731 rows x 2 columns]

# %%
# loc method is used to retrive info ththrough labels
# main differnece between iloc and loc
# we did not assign indexing at this data set hence
# below code is not functioning
#data.loc['Adelphi University', :]

# %%
# explicit index: loc indexer or loc accessor
# this is used by referring to index labels

data.loc[0:2]
# Out:
#                          school Private  Accept.pct  Elite10  F.Undergrad  \
# 0  Abilene Christian University     Yes    0.742169        0         2885
# 1            Adelphi University     Yes    0.880146        0         2683
# 2                Adrian College     Yes    0.768207        0         1036
#
#    P.Undergrad  Outstate  Room.Board  Books  Personal  PhD  Terminal  \
# 0          537      7440        3300    450      2200   70        78
# 1         1227     12280        6450    750      1500   29        30
# 2           99     11250        3750    400      1165   53        66
#
#    S.F.Ratio  perc.alumni  Expend  Grad.Rate
# 0       18.1           12    7041         60
# 1       12.2           16   10527         56
# 2       12.9           30    8735         54

# %%
data.loc[:, 'Private']
# Out:
# 0      Yes
# 1      Yes
# 2      Yes
# 3      Yes
# 4      Yes
#       ...
# 726    Yes
# 727    Yes
# 728     No
# 729    Yes
# 730    Yes
# Name: Private, Length: 731, dtype: object

# %%
data.loc[1, 'Private'] # perfect indication of explicit labeling
# remember this is a series and not paranthesis
# Out:
# 'Yes'

# %%
data = pd.read_csv('college.csv', index_col='school')
data
# Out:
#                                 Private  Accept.pct  Elite10  F.Undergrad  \
# school
# Abilene Christian University        Yes    0.742169        0         2885
# Adelphi University                  Yes    0.880146        0         2683
# Adrian College                      Yes    0.768207        0         1036
# Agnes Scott College                 Yes    0.836930        1          510
# Alaska Pacific University           Yes    0.756477        0          249
# ...                                 ...         ...      ...          ...
# Wofford College                     Yes    0.622918        1         1059
# Worcester Polytechnic Institute     Yes    0.835983        0         2802
# Worcester State College              No    0.689577        0         3089
# Xavier University                   Yes    0.921388        0         2849
# Xavier University of Louisiana      Yes    0.913209        0         2793
#
# ...

# %%
# to apply loc method which means index labeling
data.loc['Alaska Pacific University', :]
# Out:
# Private             Yes
# Accept.pct     0.756477
# Elite10               0
# F.Undergrad         249
# P.Undergrad         869
# Outstate           7560
# Room.Board         4120
# Books               800
# Personal           1500
# PhD                  76
# Terminal             72
# S.F.Ratio          11.9
# perc.alumni           2
# Expend            10922
# Grad.Rate            15
# Name: Alaska Pacific University, dtype: object

# %%
data.loc['Alaska Pacific University', 'Private']
# Out:
# 'Yes'

# %%
data.loc[['Alaska Pacific University', 'Wofford College'], :]
# Out:
#                           Private  Accept.pct  Elite10  F.Undergrad  \
# school
# Alaska Pacific University     Yes    0.756477        0          249
# Wofford College               Yes    0.622918        1         1059
#
#                            P.Undergrad  Outstate  Room.Board  Books  Personal  \
# school
# Alaska Pacific University          869      7560        4120    800      1500
# Wofford College                     34     12680        4150    605      1440
#
#                            PhD  Terminal  S.F.Ratio  perc.alumni  Expend  \
# school
# Alaska Pacific University   76        72       11.9            2   10922
# Wofford College             91        92       15.3           42    7875
#
#                            Grad.Rate
# school
# Alaska Pacific University         15
# Wofford College                   75

# %%
data.loc[['Alaska Pacific University', 'Wofford College'], ['Outstate', 'Private']]
# Out:
#                            Outstate Private
# school
# Alaska Pacific University      7560     Yes
# Wofford College               12680     Yes

# %%
array_a = np.array([[2,3,4], [3,4,5]])
array_a
# Out:
# array([[2, 3, 4],
#        [3, 4, 5]])

# %%
array_a[0]
# Out:
# array([2, 3, 4])

# %%
array_a[1]
# Out:
# array([3, 4, 5])

# %%
r = pd.DataFrame(array_a,columns=['Col1 ', 'Col2', 'Col3'],
                index=['row1', 'row2'])
r
# Out:
#       Col1   Col2  Col3
# row1      2     3     4
# row2      3     4     5

# %%
r.loc['row1', :]
# Out:
# Col1     2
# Col2     3
# Col3     4
# Name: row1, dtype: int32

# %%
r.loc['row2', 'Col3']
# Out:
# 5

# %%
array_a
# Out:
# array([[2, 3, 4],
#        [3, 4, 5]])

# %%
array_a[0][2] # implcitly acces 4
# Out:
# 4

# %%
r.iloc[:, [1,2]] # slicing technique
# Out:
#       Col2  Col3
# row1     3     4
# row2     4     5

# %%
array_a.shape
# Out:
# (2, 3)

# %%
len(array_a)
# Out:
# 2

# %%
array_b = np.array([1,2,3])
array_b[-1]
# Out:
# 3

# %%
array_a[-1]
# Out:
# array([3, 4, 5])

# %%
# Assigning Values:
array_a
# Out:
# array([[2, 3, 4],
#        [3, 4, 5]])

# %%
array_a[0][2] = 3

# %%
array_a
# Out:
# array([[2, 3, 3],
#        [3, 4, 5]])

# %%
array_a[0]=0 # assigning all elements at o index 
array_a
# Out:
# array([[0, 0, 0],
#        [3, 4, 5]])

# %%
array_a[:][1] = 9
array_a
# Out:
# array([[0, 0, 0],
#        [9, 9, 9]])

# %%
array_a[:] =10
array_a
# Out:
# array([[10, 10, 10],
#        [10, 10, 10]])

# %%
array_a +2
# Out:
# array([[12, 12, 12],
#        [12, 12, 12]])

# %%
array_a
# Out:
# array([[10, 10, 10],
#        [10, 10, 10]])

# %%
array_a-2
# Out:
# array([[8, 8, 8],
#        [8, 8, 8]])

# %%
list1 = [1,2,3]
list1+[2]
# Out:
# [1, 2, 3, 2]

# %%
array_a + array_b+[2]
# Out:
# array([[13, 14, 15],
#        [13, 14, 15]])

# %%
array_a
# Out:
# array([[10, 10, 10],
#        [10, 10, 10]])

# %%
array_b
# Out:
# array([1, 2, 3])

# %%
array_b - array_a
# Out:
# array([[-9, -8, -7],
#        [-9, -8, -7]])

# %%
array_a-array_b # order is always important (don't forget)
# Out:
# array([[9, 8, 7],
#        [9, 8, 7]])

# %%
# the different data types numpy can support
# how changing the type of data affect in how we see the data it stores
array_a = np.array([[3,4,5], [2,3,4]])

# %%
array_a
# Out:
# array([[3, 4, 5],
#        [2, 3, 4]])

# %%
# dataset to be of specific kind
array_a = np.array([[3,4,5,2], [455,3,2,2]], dtype = "float32")

# %%
array_a
# Out:
# array([[  3.,   4.,   5.,   2.],
#        [455.,   3.,   2.,   2.]], dtype=float32)

# %%
array_a = np.array([[3,4,5,2], [455,3,2,2]], dtype = "complex64")

# %%
array_a = np.array([[3,4,5,2], [455,3,2,2]], dtype = "int32")
array_a
# Out:
# array([[  3,   4,   5,   2],
#        [455,   3,   2,   2]])

# %%
array_a = np.array([[3,4,5,2], [455,3,2,2]], dtype = np.int32)
array_a
# Out:
# array([[  3,   4,   5,   2],
#        [455,   3,   2,   2]])

# %%
array_a = np.array([[3,4,5,2], [455,3,2,2]], dtype = np.float64)
array_a
# Out:
# array([[  3.,   4.,   5.,   2.],
#        [455.,   3.,   2.,   2.]])

# %%
# how numpy works with complex numbers:
# real + img part
array_a = np.array([[3,4,5,2], [455,3,2,2]], dtype = np.complex64)
array_a
# Out:
# array([[  3.+0.j,   4.+0.j,   5.+0.j,   2.+0.j],
#        [455.+0.j,   3.+0.j,   2.+0.j,   2.+0.j]], dtype=complex64)

# %%
array_a = np.array([[3,4,5,2], [455,3,2,2]], dtype = np.bool_)
array_a
# Out:
# array([[ True,  True,  True,  True],
#        [ True,  True,  True,  True]])

# %%
array_a = np.array([[3,4,5,2], [455,3,2,2]], dtype = np.str_)
array_a # different sub types of strings
# Out:
# array([['3', '4', '5', '2'],
#        ['455', '3', '2', '2']], dtype='<U3')

# %%
# Fundamentals of Numpy Functions:
# Type Chasting: Taking every element of an array
# and changing it to a specified datatype

# Attribute chaining and method chaining (Two important concepts)



# Let's practice Type Casting:
array_1 = ([[3,4,4], [765,4,5]])
array_2 = ([[3,2,3], [4,2,4]])

# this will convert all elements into float and then add them up

np.add(array_1, array_2, dtype = np.float32)
# Out:
# array([[  6.,   6.,   7.],
#        [769.,   6.,   9.]], dtype=float32)

# %%
# Substentially it thorws an error becaue it will convert all elements
# first into strng and then adds them up

#np.add(array_1, array_2, dtype = np.str_)

# %%
# Running function along an axis
a=2<<2 
print(a)
# Out:
# 8
